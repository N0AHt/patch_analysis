# %%
#imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from skimage import io

import skvideo
skvideo.setFFmpegPath('/Applications/ffmpeg-20200102-81172b5-macos64-shared/bin')
import skvideo.io as io

# %%
import os
os.listdir()
# Out:
# ['gcamp.ipynb',
#  '.DS_Store',
#  'test.py',
#  'utils.py',
#  'vis.ipynb',
#  '.ipynb_checkpoints',
#  '.git',
#  'data',
#  'cgm.ipynb',
#  '.idea']

# %%
#correct photobleaching

vid = io.vread('data/calcium/moi2mil_60x.avi')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 #correct photobleaching
# ----> 3 vid = io.vread('data/calcium/moi2mil_60x.avi')
#
# File ~/opt/anaconda3/envs/analysis/lib/python3.12/site-packages/skvideo/io/io.py:144, in vread(fname, height, width, num_frames, as_grey, inputdict, outputdict, backend, verbosity)
#     141 if as_grey:
#     142     outputdict['-pix_fmt'] = 'gray'
# --> 144 reader = FFmpegReader(fname, inputdict=inputdict, outputdict=outputdict, verbosity=verbosity)
#     145 T, M, N, C = reader.getShape()
#     147 videodata = np.empty((T, M, N, C), dtype=reader.dtype)
#
# File ~/opt/anaconda3/envs/analysis/lib/python3.12/site-packages/skvideo/io/ffmpeg.py:44, in FFmpegReader.__init__(self, *args, **kwargs)
#      42 def __init__(self, *args, **kwargs):
# ...

# %%
paths = ['data/calcium/Values.csv', 'data/calcium/Values2.csv', 'data/calcium/Values3.csv']
spikes = [pd.read_csv(path) for path in paths]

# %%
plt.plot(spikes[0].Mean.values)
plt.title('dF/F')
plt.ylabel('Fluorescence a.u.')
plt.xlabel('Frame #')
plt.show()

# %%
plt.plot(spikes[1].Mean.values)
plt.plot(spikes[2].Mean.values)
plt.title('dF/F')
plt.ylabel('Fluorescence a.u.')
plt.xlabel('Frame #')
plt.show()
